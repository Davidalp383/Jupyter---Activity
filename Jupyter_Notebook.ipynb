# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # My exercise with Jupyter

# %% [markdown]
# ## Exploring Data Science Tools and Techniques in JupyterLite.

# %% [markdown]
# ### Data Science Languages
# 1. Python
# 2. R
# 3. Julia

# %% [markdown]
# ### Data Science Libraries
# - Pandas
# - NumPy
# - Matplotlib

# %% [markdown]
# ### Data Science Tools
#
# | Herramienta         | Descripción                      |
# |---------------------|----------------------------------|
# | Jupyter Notebook    | Entorno interactivo de codificación y análisis |
# | TensorFlow          | Biblioteca de aprendizaje automático |
# | Scikit-learn        | Biblioteca para aprendizaje automático en Python |

# %% [markdown]
# ## Examples of Arithmetic Expressions
# 1. Suma: \( 5 + 3 \)
# 2. Multiplicación: \( 2 \times 4 \)
# 3. División: \( \frac{10}{2} \)

# %%
# Multiplicación y suma de números
a = 5
b = 10
resultado_multiplicacion = a * b
resultado_suma = a + b

print(f"Multiplicación: {resultado_multiplicacion}")
print(f"Suma: {resultado_suma}")

# %%
# Conversion from Minutes to Hours
minutos = 120
horas = minutos / 60

print(f"{minutos} minutos equivalen a {horas} horas")

# %% [markdown]
# ### Objectives
# 1. ...
# 2. ...
# 3. ...

# %% [markdown]
# ## Author: David Alejandro Lopez Sanchez
